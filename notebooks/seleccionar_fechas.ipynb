# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv("../dat/datos_ruoa_esolmet.csv", index_col=0, 
                   parse_dates=True)
datos.index
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 00:10:00',
#                '2018-01-01 00:20:00', '2018-01-01 00:30:00',
#                '2018-01-01 00:40:00', '2018-01-01 00:50:00',
#                '2018-01-01 01:00:00', '2018-01-01 01:10:00',
#                '2018-01-01 01:20:00', '2018-01-01 01:30:00',
#                ...
#                '2018-12-31 22:20:00', '2018-12-31 22:30:00',
#                '2018-12-31 22:40:00', '2018-12-31 22:50:00',
#                '2018-12-31 23:00:00', '2018-12-31 23:10:00',
#                '2018-12-31 23:20:00', '2018-12-31 23:30:00',
#                '2018-12-31 23:40:00', '2018-12-31 23:50:00'],
#               dtype='datetime64[ns]', length=52560, freq=None)

# %%
datos[["Ig_esolmet","Ig_ruoa"]].plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
datos.loc["2018-11"][["Ig_esolmet","Ig_ruoa"]].plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
datos[datos.index.month == 11][["Ig_esolmet","Ig_ruoa"]].plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
datos.index.day_of_week.unique()
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64')

# %%
datos[datos.index.day_of_week > 4][["Ig_esolmet","Ig_ruoa"]].plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
datos[(datos.index.day_of_week > 4 ) & (datos.index.month==1)][["Ig_esolmet","Ig_ruoa"]].plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
datos.index.month_name().unique()
# Out:
# Index(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype='object')

# %%
fin = datos.truncate(before="2018-11-09",after="2018-11-10")

# %%
fin.Ig_esolmet.plot()
# Out:
# <AxesSubplot:>

# %%
datos.plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)
